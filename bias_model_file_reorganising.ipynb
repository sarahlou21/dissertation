# %%
# Make a copy of the data, and reorganise  each of the folder (train, val and test) so that within each folder
# the 7 non-mel class subfodlers are merged, so that it results in two folders MEL and NONMEL
